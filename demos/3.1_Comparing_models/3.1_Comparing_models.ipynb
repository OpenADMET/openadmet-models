# %% [markdown]
# # 3.1 Comparing models
# ### Background
# After training multiple models with Anvil, you will want to compare the performance across models in a robust way. We closely follow the guidlines laid out in [this paper](https://chemrxiv.org/engage/chemrxiv/article-details/672a91bd7be152b1d01a926b). Consider the below decision chart for helping figure out which models to compare:
#
# <div style="text-align: center">
# <img src="comparison_guidelines.png" alt="Model comparison" width="500"/>.
# </div>
#
# ### Requirements
# For this demo, you will need:
# 1. At least 2 models trained with the Anvil workflow.
# ## 1. Overview
# This notebook will walk you through how to use the OpenADMET CLI to evaluate models that have been trained with the Anvil workflow. In this particular demo, we will compare the two models we trained in `2.1_Training_models_with_Anvil.ipynb`: LightGBM and Chemprop.
#
# ## 2. Comparing the models
# As with training models with Anvil, comparing models is also a simple command with the following arguments:
# ```
# openadmet compare \
# --model-stats <path/cross_validation_metrics.json> \
# --model-tag <a-tag-to-label-your-trained-model> \
# --model-stats <path2/cross_validation_metrics.json> \
# --model-tag <a-second-tag-to-label-your-trained-model> \
# --output-dir <path-to-output-plots> \
# --report <whether-or-not-to-write-pdf-report>
# ```
#
# For this demo, this command is:

# %%
# %%bash
# openadmet compare \
#     --model-stats ../2.1_Training_models_with_Anvil/anvil_training/cross_validation_metrics.json \
#     --model-tag lgbm-PXR-chembl \
#     --model-stats ../2.1_Training_models_with_Anvil/anvil_training_2025-07-14_86073d/cross_validation_metrics.json \
#     --model-tag chemprop-PXR-chembl \
#     --output-dir model_comparisons/ \
#     --report True
# Out:
# Traceback (most recent call last):
#   File "/Users/cynthiaxu/miniconda3/envs/openadmet/bin/openadmet", line 8, in <module>
#     sys.exit(cli())
#              ^^^^^
#   File "/Users/cynthiaxu/miniconda3/envs/openadmet/lib/python3.12/site-packages/click/core.py", line 1161, in __call__
#     return self.main(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/cynthiaxu/miniconda3/envs/openadmet/lib/python3.12/site-packages/click/core.py", line 1082, in main
#     rv = self.invoke(ctx)
#          ^^^^^^^^^^^^^^^^
#   File "/Users/cynthiaxu/miniconda3/envs/openadmet/lib/python3.12/site-packages/click/core.py", line 1697, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/cynthiaxu/miniconda3/envs/openadmet/lib/python3.12/site-packages/click/core.py", line 1443, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/cynthiaxu/miniconda3/envs/openadmet/lib/python3.12/site-packages/click/core.py", line 788, in invoke
#     return __callback(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/cynthiaxu/Documents/Coding Projects/OMSF/openadmet-models/openadmet/models/cli/compare.py", line 43, in compare
#     raise NotImplementedError
# NotImplementedError
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', 'openadmet compare \\\n    --model-stats ../2.1_Training_models_with_Anvil/anvil_training/cross_validation_metrics.json \\\n    --model-tag lgbm-PXR-chembl \\\n    --model-stats ../2.1_Training_models_with_Anvil/anvil_training_2025-07-14_86073d/cross_validation_metrics.json \\\n    --model-tag chemprop-PXR-chembl \\\n    --output-dir model_comparisons/ \\\n    --report True\n')
#
# File ~/miniconda3/envs/openadmet/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2547, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2545 with self.builtin_trap:
#    2546     args = (magic_arg_s, cell)
# -> 2547     result = fn(*args, **kwargs)
#    2549 # The code below prevents the output from being displayed
#    2550 # when using magics with decorator @output_can_be_silenced
#    2551 # when the last Python token in the expression is a ';'.
#    2552 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/miniconda3/envs/openadmet/lib/python3.12/site-packages/IPython/core/magics/script.py:159, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     157 else:
#     158     line = script
# --> 159 return self.shebang(line, cell)
#
# File ~/miniconda3/envs/openadmet/lib/python3.12/site-packages/IPython/core/magics/script.py:336, in ScriptMagics.shebang(self, line, cell)
#     331 if args.raise_error and p.returncode != 0:
#     332     # If we get here and p.returncode is still None, we must have
#     333     # killed it but not yet seen its return code. We don't wait for it,
#     334     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     335     rc = p.returncode or -9
# --> 336     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'openadmet compare \\\n    --model-stats ../2.1_Training_models_with_Anvil/anvil_training/cross_validation_metrics.json \\\n    --model-tag lgbm-PXR-chembl \\\n    --model-stats ../2.1_Training_models_with_Anvil/anvil_training_2025-07-14_86073d/cross_validation_metrics.json \\\n    --model-tag chemprop-PXR-chembl \\\n    --output-dir model_comparisons/ \\\n    --report True\n'' returned non-zero exit status 1.
